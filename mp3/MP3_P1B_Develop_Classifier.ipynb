# %% [markdown]
# # Assignment 3 Part 1: Developing Your Own Classifier

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier import SimpleClassifier, Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

from torch.optim.lr_scheduler import StepLR

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Part 1B: Design your own network
#
# In this notebook, your task is to create and train your own model for multi-label classification on VOC Pascal.
#
# ## What to do
# 1. You will make change on network architecture in ```classifier.py```.
# 2. You may also want to change other hyperparameters to assist your training to get a better performances. Hints will be given in the below instructions.
#
# ## What to submit
# Check the submission template for details what to submit.

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels, _) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels, _) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %%
def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %% [markdown]
# # Developing Your Own Model

# %% [markdown]
# ### Goal
# To meet the benchmark for this assignment you will need to improve the network. Note you should have noticed pretrained Alenxt performs really well, but training Alexnet from scratch performs much worse. We hope you can design a better architecture over both the simple classifier and AlexNet to train from scratch.
#
# ### How to start
# You may take inspiration from other published architectures and architectures discussed in lecture. However, you are NOT allowed to use predefined models (e.g. models from torchvision) or use pretrained weights. Training must be done from scratch with your own custom model.
#
# #### Some hints
# There are a variety of different approaches you should try to improve performance from the simple classifier:
#
# * Network architecture changes
#     * Number of layers: try adding layers to make your network deeper
#     * Batch normalization: adding batch norm between layers will likely give you a significant performance increase
#     * Residual connections: as you increase the depth of your network, you will find that having residual connections like those in ResNet architectures will be helpful
# * Optimizer: Instead of plain SGD, you may want to add a learning rate schedule, add momentum, or use one of the other optimizers you have learned about like Adam. Check the `torch.optim` package for other optimizers
# * Data augmentation: You should use the `torchvision.transforms` module to try adding random resized crops and horizontal flips of the input data. Check `transforms.RandomResizedCrop` and `transforms.RandomHorizontalFlip` for this. Feel free to apply more [transforms](https://pytorch.org/docs/stable/torchvision/transforms.html) for data augmentation which can lead to better performance.
# * Epochs: Once you have found a generally good hyperparameter setting try training for more epochs
# * Loss function: You might want to add weighting to the `MultiLabelSoftMarginLoss` for classes that are less well represented or experiment with a different loss function
#
#
#
# #### Note
# We will soon be providing some initial expectations of mAP values as a function of epoch so you can get an early idea whether your implementation works without waiting a long time for training to converge.
#
# ### What to submit
# Submit your best model to Kaggle and save all plots for the writeup.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize
        ])

test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

ds_train = VocDataset('VOCdevkit_2007/VOC2007/','train',train_transform)
ds_val = VocDataset('VOCdevkit_2007/VOC2007/','val',test_transform)
ds_test = VocDataset('VOCdevkit_2007/VOC2007test/','test', test_transform)

# %%
num_epochs = 50
test_frequency = 5
batch_size = 16

train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=batch_size, 
                                               shuffle=False,
                                               num_workers=1)

# %%
# TODO: Run your own classifier here
classifier = Classifier().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9, weight_decay=0.001)
# optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4,weight_decay=0.001)

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.2661794126033783
# -------  Class: aeroplane        AP:   0.3818  -------
# -------  Class: bicycle          AP:   0.0959  -------
# -------  Class: bird             AP:   0.1289  -------
# -------  Class: boat             AP:   0.1243  -------
# -------  Class: bottle           AP:   0.1008  -------
# -------  Class: bus              AP:   0.0956  -------
# -------  Class: car              AP:   0.2961  -------
# -------  Class: cat              AP:   0.1836  -------
# -------  Class: chair            AP:   0.2433  -------
# -------  Class: cow              AP:   0.0401  -------
# -------  Class: diningtable      AP:   0.1745  -------
# -------  Class: dog              AP:   0.1473  -------
# -------  Class: horse            AP:   0.1296  -------
# -------  Class: motorbike        AP:   0.1298  -------
# -------  Class: person           AP:   0.5390  -------
# -------  Class: pottedplant      AP:   0.1200  -------
# -------  Class: sheep            AP:   0.0306  -------
# -------  Class: sofa             AP:   0.1509  -------
# -------  Class: train            AP:   0.1666  -------
# -------  Class: tvmonitor        AP:   0.0844  -------
# mAP: 0.1682
# Avg loss: 0.2245674098183395
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.1681573239019572
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.22682470083236694
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.21806971728801727
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.2124597430229187
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.20363909006118774
# -------  Class: aeroplane        AP:   0.4979  -------
# -------  Class: bicycle          AP:   0.2377  -------
# -------  Class: bird             AP:   0.1785  -------
# -------  Class: boat             AP:   0.2960  -------
# -------  Class: bottle           AP:   0.1244  -------
# -------  Class: bus              AP:   0.1942  -------
# -------  Class: car              AP:   0.5097  -------
# -------  Class: cat              AP:   0.2997  -------
# -------  Class: chair            AP:   0.3543  -------
# -------  Class: cow              AP:   0.0935  -------
# -------  Class: diningtable      AP:   0.2607  -------
# -------  Class: dog              AP:   0.2025  -------
# -------  Class: horse            AP:   0.3423  -------
# -------  Class: motorbike        AP:   0.2351  -------
# -------  Class: person           AP:   0.6596  -------
# -------  Class: pottedplant      AP:   0.1265  -------
# -------  Class: sheep            AP:   0.1696  -------
# -------  Class: sofa             AP:   0.2164  -------
# -------  Class: train            AP:   0.2858  -------
# -------  Class: tvmonitor        AP:   0.1795  -------
# mAP: 0.2732
# Avg loss: 0.19787469079160386
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.27320019231969617
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.20016515254974365
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.1963277906179428
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.19073747098445892
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.18689392507076263
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.18326298892498016
# -------  Class: aeroplane        AP:   0.5837  -------
# -------  Class: bicycle          AP:   0.2705  -------
# -------  Class: bird             AP:   0.1773  -------
# -------  Class: boat             AP:   0.2865  -------
# -------  Class: bottle           AP:   0.1234  -------
# -------  Class: bus              AP:   0.1998  -------
# -------  Class: car              AP:   0.5598  -------
# -------  Class: cat              AP:   0.3362  -------
# -------  Class: chair            AP:   0.3890  -------
# -------  Class: cow              AP:   0.1400  -------
# -------  Class: diningtable      AP:   0.2932  -------
# -------  Class: dog              AP:   0.2316  -------
# -------  Class: horse            AP:   0.4186  -------
# -------  Class: motorbike        AP:   0.2602  -------
# -------  Class: person           AP:   0.7034  -------
# -------  Class: pottedplant      AP:   0.1516  -------
# -------  Class: sheep            AP:   0.1452  -------
# -------  Class: sofa             AP:   0.2674  -------
# -------  Class: train            AP:   0.4125  -------
# -------  Class: tvmonitor        AP:   0.2431  -------
# mAP: 0.3097
# Avg loss: 0.19279971519473252
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.3096503718685675
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.1787111461162567
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.17702651023864746
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.17227758467197418
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.17003141343593597
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.166653573513031
# -------  Class: aeroplane        AP:   0.6115  -------
# -------  Class: bicycle          AP:   0.2883  -------
# -------  Class: bird             AP:   0.2368  -------
# -------  Class: boat             AP:   0.2943  -------
# -------  Class: bottle           AP:   0.1380  -------
# -------  Class: bus              AP:   0.2200  -------
# -------  Class: car              AP:   0.5652  -------
# -------  Class: cat              AP:   0.3659  -------
# -------  Class: chair            AP:   0.4407  -------
# -------  Class: cow              AP:   0.1467  -------
# -------  Class: diningtable      AP:   0.3438  -------
# -------  Class: dog              AP:   0.2455  -------
# -------  Class: horse            AP:   0.4841  -------
# -------  Class: motorbike        AP:   0.3506  -------
# -------  Class: person           AP:   0.7384  -------
# -------  Class: pottedplant      AP:   0.1774  -------
# -------  Class: sheep            AP:   0.1691  -------
# -------  Class: sofa             AP:   0.2657  -------
# -------  Class: train            AP:   0.5105  -------
# -------  Class: tvmonitor        AP:   0.2986  -------
# mAP: 0.3446
# Avg loss: 0.1827899323906868
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.3445549487629814
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.16530561447143555
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.16164624691009521
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.15827611088752747
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.15573911368846893
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.1522178202867508
# -------  Class: aeroplane        AP:   0.6443  -------
# -------  Class: bicycle          AP:   0.3942  -------
# -------  Class: bird             AP:   0.3199  -------
# -------  Class: boat             AP:   0.4067  -------
# -------  Class: bottle           AP:   0.1766  -------
# -------  Class: bus              AP:   0.2473  -------
# -------  Class: car              AP:   0.6018  -------
# -------  Class: cat              AP:   0.3810  -------
# -------  Class: chair            AP:   0.4623  -------
# -------  Class: cow              AP:   0.1670  -------
# -------  Class: diningtable      AP:   0.3968  -------
# -------  Class: dog              AP:   0.2700  -------
# -------  Class: horse            AP:   0.5154  -------
# -------  Class: motorbike        AP:   0.3668  -------
# -------  Class: person           AP:   0.7558  -------
# -------  Class: pottedplant      AP:   0.1964  -------
# -------  Class: sheep            AP:   0.1856  -------
# -------  Class: sofa             AP:   0.2798  -------
# -------  Class: train            AP:   0.5576  -------
# -------  Class: tvmonitor        AP:   0.3281  -------
# mAP: 0.3827
# Avg loss: 0.17771882601794164
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.3826825896216813
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.14930324256420135
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.14767436683177948
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.1440354883670807
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.14034689962863922
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.13757601380348206
# -------  Class: aeroplane        AP:   0.6089  -------
# -------  Class: bicycle          AP:   0.3132  -------
# -------  Class: bird             AP:   0.2769  -------
# -------  Class: boat             AP:   0.4258  -------
# -------  Class: bottle           AP:   0.1949  -------
# -------  Class: bus              AP:   0.3324  -------
# -------  Class: car              AP:   0.6109  -------
# -------  Class: cat              AP:   0.3889  -------
# -------  Class: chair            AP:   0.4638  -------
# -------  Class: cow              AP:   0.1647  -------
# -------  Class: diningtable      AP:   0.4027  -------
# -------  Class: dog              AP:   0.2976  -------
# -------  Class: horse            AP:   0.5191  -------
# -------  Class: motorbike        AP:   0.4895  -------
# -------  Class: person           AP:   0.7724  -------
# -------  Class: pottedplant      AP:   0.1779  -------
# -------  Class: sheep            AP:   0.1982  -------
# -------  Class: sofa             AP:   0.2848  -------
# -------  Class: train            AP:   0.6199  -------
# -------  Class: tvmonitor        AP:   0.3530  -------
# mAP: 0.3948
# Avg loss: 0.18225361430531095
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 25 is 0.39476950540054656
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.13533301651477814
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.1341550499200821
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.1293378323316574
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.12775424122810364
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.12328486144542694
# -------  Class: aeroplane        AP:   0.6428  -------
# -------  Class: bicycle          AP:   0.3966  -------
# -------  Class: bird             AP:   0.2627  -------
# -------  Class: boat             AP:   0.4399  -------
# -------  Class: bottle           AP:   0.1854  -------
# -------  Class: bus              AP:   0.3044  -------
# -------  Class: car              AP:   0.6040  -------
# -------  Class: cat              AP:   0.3840  -------
# -------  Class: chair            AP:   0.4783  -------
# -------  Class: cow              AP:   0.1839  -------
# -------  Class: diningtable      AP:   0.3919  -------
# -------  Class: dog              AP:   0.2860  -------
# -------  Class: horse            AP:   0.5290  -------
# -------  Class: motorbike        AP:   0.4686  -------
# -------  Class: person           AP:   0.7756  -------
# -------  Class: pottedplant      AP:   0.1838  -------
# -------  Class: sheep            AP:   0.1715  -------
# -------  Class: sofa             AP:   0.3126  -------
# -------  Class: train            AP:   0.6371  -------
# -------  Class: tvmonitor        AP:   0.3462  -------
# mAP: 0.3992
# Avg loss: 0.1792204228650992
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 30 is 0.39920983213554245
# Starting epoch number 31
# Loss for Training on Epoch 31 is 0.12199253588914871
# Starting epoch number 32
# Loss for Training on Epoch 32 is 0.11904899775981903
# Starting epoch number 33
# Loss for Training on Epoch 33 is 0.11553820222616196
# Starting epoch number 34
# Loss for Training on Epoch 34 is 0.11458558589220047
# Starting epoch number 35
# Loss for Training on Epoch 35 is 0.11132519692182541
# -------  Class: aeroplane        AP:   0.6530  -------
# -------  Class: bicycle          AP:   0.4074  -------
# -------  Class: bird             AP:   0.2786  -------
# -------  Class: boat             AP:   0.4202  -------
# -------  Class: bottle           AP:   0.1560  -------
# -------  Class: bus              AP:   0.3333  -------
# -------  Class: car              AP:   0.5791  -------
# -------  Class: cat              AP:   0.3193  -------
# -------  Class: chair            AP:   0.4511  -------
# -------  Class: cow              AP:   0.1800  -------
# -------  Class: diningtable      AP:   0.3228  -------
# -------  Class: dog              AP:   0.2949  -------
# -------  Class: horse            AP:   0.5132  -------
# -------  Class: motorbike        AP:   0.4627  -------
# -------  Class: person           AP:   0.7575  -------
# -------  Class: pottedplant      AP:   0.1696  -------
# -------  Class: sheep            AP:   0.1914  -------
# -------  Class: sofa             AP:   0.2546  -------
# -------  Class: train            AP:   0.6346  -------
# -------  Class: tvmonitor        AP:   0.2784  -------
# mAP: 0.3829
# Avg loss: 0.19641250101434196
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 35 is 0.3828820775695461
# Starting epoch number 36
# Loss for Training on Epoch 36 is 0.10819720476865768
# Starting epoch number 37
# Loss for Training on Epoch 37 is 0.10662005841732025
# Starting epoch number 38
# Loss for Training on Epoch 38 is 0.10505928844213486
# Starting epoch number 39
# Loss for Training on Epoch 39 is 0.10125651210546494
# Starting epoch number 40
# Loss for Training on Epoch 40 is 0.0955183207988739
# -------  Class: aeroplane        AP:   0.6314  -------
# -------  Class: bicycle          AP:   0.4245  -------
# -------  Class: bird             AP:   0.2949  -------
# -------  Class: boat             AP:   0.4277  -------
# -------  Class: bottle           AP:   0.1643  -------
# -------  Class: bus              AP:   0.3257  -------
# -------  Class: car              AP:   0.6010  -------
# -------  Class: cat              AP:   0.3513  -------
# -------  Class: chair            AP:   0.4771  -------
# -------  Class: cow              AP:   0.1648  -------
# -------  Class: diningtable      AP:   0.3465  -------
# -------  Class: dog              AP:   0.2748  -------
# -------  Class: horse            AP:   0.5150  -------
# -------  Class: motorbike        AP:   0.4894  -------
# -------  Class: person           AP:   0.7625  -------
# -------  Class: pottedplant      AP:   0.2026  -------
# -------  Class: sheep            AP:   0.1578  -------
# -------  Class: sofa             AP:   0.2905  -------
# -------  Class: train            AP:   0.6355  -------
# -------  Class: tvmonitor        AP:   0.3167  -------
# mAP: 0.3927
# Avg loss: 0.1945047589718916
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 40 is 0.3926964516158482
# Starting epoch number 41
# Loss for Training on Epoch 41 is 0.09644343703985214
# Starting epoch number 42
# Loss for Training on Epoch 42 is 0.09390035271644592
# Starting epoch number 43
# Loss for Training on Epoch 43 is 0.08942458778619766
# Starting epoch number 44
# Loss for Training on Epoch 44 is 0.08672866225242615
# Starting epoch number 45
# Loss for Training on Epoch 45 is 0.08501140773296356
# -------  Class: aeroplane        AP:   0.6152  -------
# -------  Class: bicycle          AP:   0.3580  -------
# -------  Class: bird             AP:   0.2403  -------
# -------  Class: boat             AP:   0.4939  -------
# -------  Class: bottle           AP:   0.1790  -------
# -------  Class: bus              AP:   0.2837  -------
# -------  Class: car              AP:   0.5987  -------
# -------  Class: cat              AP:   0.3878  -------
# -------  Class: chair            AP:   0.4657  -------
# -------  Class: cow              AP:   0.1281  -------
# -------  Class: diningtable      AP:   0.3578  -------
# -------  Class: dog              AP:   0.2494  -------
# -------  Class: horse            AP:   0.5282  -------
# -------  Class: motorbike        AP:   0.3796  -------
# -------  Class: person           AP:   0.7393  -------
# -------  Class: pottedplant      AP:   0.1602  -------
# -------  Class: sheep            AP:   0.1844  -------
# -------  Class: sofa             AP:   0.2907  -------
# -------  Class: train            AP:   0.6506  -------
# -------  Class: tvmonitor        AP:   0.3154  -------
# mAP: 0.3803
# Avg loss: 0.20632136674823276
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 45 is 0.3802999409841166
# Starting epoch number 46
# Loss for Training on Epoch 46 is 0.0844549909234047
# Starting epoch number 47
# Loss for Training on Epoch 47 is 0.08430428802967072
# Starting epoch number 48
# Loss for Training on Epoch 48 is 0.07926535606384277
# Starting epoch number 49
# Loss for Training on Epoch 49 is 0.0784037634730339
# Starting epoch number 50
# Loss for Training on Epoch 50 is 0.0715898722410202
# -------  Class: aeroplane        AP:   0.6183  -------
# -------  Class: bicycle          AP:   0.3930  -------
# -------  Class: bird             AP:   0.2963  -------
# -------  Class: boat             AP:   0.4675  -------
# -------  Class: bottle           AP:   0.1429  -------
# -------  Class: bus              AP:   0.2917  -------
# -------  Class: car              AP:   0.5262  -------
# -------  Class: cat              AP:   0.3715  -------
# -------  Class: chair            AP:   0.4406  -------
# -------  Class: cow              AP:   0.1378  -------
# -------  Class: diningtable      AP:   0.3319  -------
# -------  Class: dog              AP:   0.2410  -------
# -------  Class: horse            AP:   0.4923  -------
# -------  Class: motorbike        AP:   0.3720  -------
# -------  Class: person           AP:   0.7447  -------
# -------  Class: pottedplant      AP:   0.1542  -------
# -------  Class: sheep            AP:   0.1754  -------
# -------  Class: sofa             AP:   0.3137  -------
# -------  Class: train            AP:   0.6880  -------
# -------  Class: tvmonitor        AP:   0.3325  -------
# mAP: 0.3766
# Avg loss: 0.20758842430107152
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 50 is 0.3765809100854198

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print(mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.6350  -------
# -------  Class: bicycle          AP:   0.3540  -------
# -------  Class: bird             AP:   0.2731  -------
# -------  Class: boat             AP:   0.4521  -------
# -------  Class: bottle           AP:   0.1434  -------
# -------  Class: bus              AP:   0.2164  -------
# -------  Class: car              AP:   0.5662  -------
# -------  Class: cat              AP:   0.3784  -------
# -------  Class: chair            AP:   0.4259  -------
# -------  Class: cow              AP:   0.1983  -------
# -------  Class: diningtable      AP:   0.2901  -------
# -------  Class: dog              AP:   0.2896  -------
# -------  Class: horse            AP:   0.6391  -------
# -------  Class: motorbike        AP:   0.3796  -------
# -------  Class: person           AP:   0.7587  -------
# -------  Class: pottedplant      AP:   0.1910  -------
# -------  Class: sheep            AP:   0.2551  -------
# -------  Class: sofa             AP:   0.2862  -------
# -------  Class: train            AP:   0.6175  -------
# -------  Class: tvmonitor        AP:   0.3103  -------
# mAP: 0.3830
# Avg loss: 0.20248368380050505
# 0.38299376267463925

# %%
torch.save(classifier.state_dict(), './voc_my_best_classifier.pth')
output_submission_csv('my_solution.csv', test_aps)
